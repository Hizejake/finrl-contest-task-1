# %% [markdown]
# # Exploratory Analysis Notebook
#
# Use this notebook for exploratory data analysis, sanity checks on the merged limit order book and news sentiment data, or to visualize the aggregated performance summary generated by `src/evaluate.py`.
